# %% [markdown]
# # Exact Keyword Search Experiment
#
# This notebook experiments with **exact keyword searches** in ADS using the `=field:"keyword"` syntax to avoid the embedding-based semantic search that returns large result sets.
#
# ## Objectives:
# 1. **Extract top keywords** from our wordcloud analysis
# 2. **Test exact searches** in different ADS fields (title, abstract, full text)
# 3. **Measure overlap** with WUMaCat bibcodes to evaluate search precision
# 4. **Compare strategies** to find optimal exact search approach
# 5. **Analyze results** and recommend best practices
#
# ## ADS Search Syntax:
# - **Semantic search**: `keyword` (uses embeddings, large results)
# - **Exact field search**: `=title:"keyword"`, `=abs:"keyword"`, `=full:"keyword"`
# - **Exact author search**: `=author:"Last, First"`
# - **Combined exact search**: `=title:"binary" AND =title:"eclipsing"` (papers containing ALL keywords)
#
# ## Methodology:
# We'll use our existing wordcloud data to extract the most relevant astronomical terms and test how well exact field searches with **AND logic** can find papers that contain ALL specified keywords. We test combinations of **20, 15, 10, 7, and 5 keywords** with an increased limit of **20,000 papers** for comprehensive analysis.

# %% [markdown]
# ## 1. Setup and Data Loading

# %%
# Setup and imports
import sys
import os
import json
from datetime import datetime

# Add the src directory to the path
sys.path.append('../src')

# Import our enhanced ADS parser functions
from ads_parser import (
    test_ads_connection, 
    search_exact_keywords, 
    test_keyword_combination_sizes
)

# Import wordcloud utilities
from wordcloud_utils import (
    load_wumacat_bibcodes,
    get_top_keywords_from_wordclouds,
    save_experiment_results
)

print("✅ Libraries imported successfully")
print("✅ New keyword combination testing function available")
print("✅ Ready for full-text keyword combination experiment!")

# Test ADS connection
print("\n🔍 Testing ADS API connection...")
if test_ads_connection():
    print("✅ ADS connection successful - ready to proceed!")
else:
    print("❌ ADS connection failed - check your API token")
# Out:
# ✅ Libraries imported successfully
# ✅ New keyword combination testing function available
# ✅ Ready for full-text keyword combination experiment!
#
# 🔍 Testing ADS API connection...
# 🔍 Testing ADS API connection...
# ✅ ADS API connection successful!
#    Found 1104 total results
#    Retrieved 1 documents
# ✅ ADS connection successful - ready to proceed!

# %% [markdown]
# ## 2. Load WUMaCat Reference Data

# %%
# Load WUMaCat bibcodes for overlap analysis
print("📂 Loading WUMaCat bibcodes for reference...")
wumacat_bibcodes = load_wumacat_bibcodes('../data/WUMaCat.csv')

print(f"\n📊 WUMaCat Reference Dataset:")
print(f"   Total unique bibcodes: {len(wumacat_bibcodes)}")

# Show a few examples
if wumacat_bibcodes:
    sample_bibcodes = list(wumacat_bibcodes)[:5]
    print(f"   Sample bibcodes: {sample_bibcodes}")
    
print("\n✅ Reference data loaded successfully!")
# Out:
# 📂 Loading WUMaCat bibcodes for reference...
# ✅ Loaded 424 unique bibcodes from WUMaCat
#
# 📊 WUMaCat Reference Dataset:
#    Total unique bibcodes: 424
#    Sample bibcodes: ['2011AJ....142...12L', '2014AJ....148...79Q', '2011RAA....11..181Y', '2019RAA....19...56H', '2020MNRAS.497.3381G']
#
# ✅ Reference data loaded successfully!

# %% [markdown]
# ## 3. Extract Top Keywords from Wordclouds

# %%
# Extract top keywords from our wordcloud frequency analysis
print("🎯 Extracting top keywords from wordcloud analysis...")

# Load keywords from wordcloud frequency files
titles_freq_file = '../wordclouds/titles_word_frequencies.json'
abstracts_freq_file = '../wordclouds/abstracts_word_frequencies.json'

# Check if files exist
if os.path.exists(titles_freq_file) and os.path.exists(abstracts_freq_file):
    # Extract top 25 keywords for testing (need at least 20 for largest combination)
    top_keywords = get_top_keywords_from_wordclouds(
        titles_freq_file, 
        abstracts_freq_file, 
        top_n=25, 
        exclude_generic=True
    )
    
    print(f"\n🔍 Top {len(top_keywords)} keywords for exact searching:")
    for i, keyword in enumerate(top_keywords, 1):
        print(f"   {i:2d}. {keyword}")
        
    print("\n✅ Keywords extracted successfully!")
    
else:
    print("❌ Wordcloud frequency files not found!")
    print("   Please run the wordcloud_analysis.ipynb notebook first.")
    
    # Fallback: use manually selected binary star keywords
    print("\n🔄 Using fallback binary star keywords...")
    top_keywords = [
        'binary', 'binaries', 'eclipsing', 'contact', 'detached', 
        'stellar', 'photometry', 'variability', 'period', 'orbital',
        'lightcurve', 'eclipse', 'companion', 'mass', 'radius',
        'magnitude', 'flux', 'brightness', 'amplitude', 'pulsation',
        'transit', 'occultation', 'synchronization', 'evolution', 'formation'
    ]
    print(f"   Using {len(top_keywords)} fallback keywords: {top_keywords}")
# Out:
# 🎯 Extracting top keywords from wordcloud analysis...
# ✅ Extracted top 25 keywords for exact searching
#
# 🔍 Top 25 keywords for exact searching:
#     1. binary
#     2. light
#     3. contact
#     4. period
#     5. photometric
#     6. mass
#     7. type
#     8. curves
#     9. binaries
#    10. eclipsing
#    11. orbital
#    12. ratio
#    13. curve
#    14. component
#    15. star
#    16. components
#    17. massive
#    18. solutions
#    19. wilson
#    20. devinney
#    21. overcontact
#    22. primary
#    23. short
#    24. stars
#    25. secondary
#
# ✅ Keywords extracted successfully!

# %% [markdown]
# ## 4. Run Comprehensive Strategy Comparison
#
# This is the main experiment - we'll test exact keyword searches across different ADS fields and measure their effectiveness by comparing overlap with our WUMaCat reference dataset.

# %%
# Run keyword combination size experiment in full text
print("🚀 Running keyword combination size experiment...")
print("This will test different numbers of keywords (20, 15, 10, 7, 5) in full-text searches")
print("using AND logic to find papers containing ALL specified keywords.")
print("Increased limit to 20,000 papers for more comprehensive results.")

# Test different combination sizes in full text
combination_sizes = [20, 15, 10, 7, 5]
print(f"\n🎯 Available keywords: {len(top_keywords)}")
print(f"📊 Testing combination sizes: {combination_sizes}")
print(f"🔍 Search field: full text (more comprehensive than titles/abstracts)")

# Run the experiment
combination_results = test_keyword_combination_sizes(
    all_keywords=top_keywords,
    wumacat_bibcodes=wumacat_bibcodes,
    combination_sizes=combination_sizes,
    source_field="full"
)

print("\n✅ Keyword combination experiment completed!")

# Display summary results
if combination_results and 'summary' in combination_results:
    summary = combination_results['summary']
    print(f"\n🎯 EXPERIMENT SUMMARY:")
    print(f"   Successful combinations: {summary.get('successful_combinations', [])}")
    
    if 'best_overlap' in summary:
        best_overlap = summary['best_overlap']
        print(f"   Best overlap: {best_overlap['percentage']:.1f}% with {best_overlap['size']} keywords")
    
    if 'best_precision' in summary:
        best_precision = summary['best_precision']
        print(f"   Best precision: {best_precision['percentage']:.1f}% with {best_precision['size']} keywords")
        
    if 'best_f1' in summary:
        best_f1 = summary['best_f1']
        print(f"   Best F1-score: {best_f1['score']:.1f}% with {best_f1['size']} keywords")
else:
    print("\n⚠️  Combination experiment did not complete successfully")
# Out:
# 🚀 Running keyword combination size experiment...
# This will test different numbers of keywords (20, 15, 10, 7, 5) in full-text searches
# using AND logic to find papers containing ALL specified keywords.
# Increased limit to 20,000 papers for more comprehensive results.
#
# 🎯 Available keywords: 25
# 📊 Testing combination sizes: [20, 15, 10, 7, 5]
# 🔍 Search field: full text (more comprehensive than titles/abstracts)
# 🧪 Testing keyword combination sizes in 'full' field
#    Available keywords: 25
#    Combination sizes to test: [20, 15, 10, 7, 5]
#    WUMaCat reference size: 424
#
# 📊 Testing combination size: 20 keywords
#    Keywords: ['binary', 'light', 'contact', 'period', 'photometric', 'mass', 'type', 'curves', 'binaries', 'eclipsing', 'orbital', 'ratio', 'curve', 'component', 'star', 'components', 'massive', 'solutions', 'wilson', 'devinney']
# 🔍 Searching for exact keywords in full field:
# ...

# %% [markdown]
# ## 5. Detailed Analysis of Combination Results
#
# Let's analyze the detailed results for each keyword combination size to understand the trade-offs between precision and recall.

# %%
# Analyze detailed results for each combination size
print("📊 DETAILED COMBINATION ANALYSIS:")
print("="*60)

if combination_results and 'combination_results' in combination_results:
    combo_results = combination_results['combination_results']
    
    # Create a summary table
    print(f"\n{'Size':<4} {'Keywords':<35} {'Found':<8} {'Overlap':<8} {'Precision':<10} {'Recall':<8} {'F1':<6}")
    print("-" * 80)
    
    for size in sorted(combo_results.keys(), reverse=True):
        data = combo_results[size]
        
        if "error" not in data:
            keywords_str = ', '.join(data['keywords'][:3]) + ('...' if len(data['keywords']) > 3 else '')
            keywords_str = keywords_str[:32] + '...' if len(keywords_str) > 35 else keywords_str
            
            found = data['total_found']
            overlap = data['overlap_count']
            precision = data.get('precision', 0)
            recall = data.get('overlap_percentage', 0)  # Same as recall in our case
            f1 = data.get('f1_score', 0)
            
            print(f"{size:<4} {keywords_str:<35} {found:<8} {overlap:<8} {precision:<10.1f} {recall:<8.1f} {f1:<6.1f}")
        else:
            print(f"{size:<4} {'ERROR':<35} {'-':<8} {'-':<8} {'-':<10} {'-':<8} {'-':<6}")
    
    print("\n💡 KEY INSIGHTS:")
    
    # Analyze trends
    successful_sizes = [size for size, data in combo_results.items() 
                       if "error" not in data and data['total_found'] > 0]
    
    if len(successful_sizes) >= 2:
        # Sort by size for trend analysis
        sorted_successful = sorted([(size, combo_results[size]) for size in successful_sizes])
        
        print(f"\n📈 TRENDS (as keyword count increases):")
        print(f"   • Total papers found: Generally decreases (more restrictive)")
        print(f"   • Precision: Generally increases (more relevant papers)")
        print(f"   • Recall: May decrease (fewer WUMaCat papers found)")
        
        # Find optimal balance
        best_balance = None
        best_balance_score = 0
        
        for size, data in sorted_successful:
            # Balance score: weighted combination of precision, recall, and reasonable count
            precision = data.get('precision', 0)
            recall = data.get('overlap_percentage', 0)
            count = data['total_found']
            
            # Prefer combinations with good precision, decent recall, and manageable count
            balance_score = (precision * 0.4 + recall * 0.4 + min(count/100, 10) * 0.2)
            
            if balance_score > best_balance_score:
                best_balance_score = balance_score
                best_balance = (size, data)
        
        if best_balance:
            size, data = best_balance
            print(f"\n🎯 RECOMMENDED COMBINATION:")
            print(f"   • {size} keywords: {data['keywords']}")
            print(f"   • Found {data['total_found']} papers total")
            print(f"   • {data['overlap_count']} WUMaCat overlaps ({data['overlap_percentage']:.1f}%)")
            print(f"   • Precision: {data.get('precision', 0):.1f}%")
            print(f"   • Good balance of precision, recall, and manageability")
    
    else:
        print("   ⚠️  Limited successful combinations for trend analysis")

else:
    print("❌ No detailed results available for analysis")

print(f"\n✅ Detailed analysis completed!")
# Out:
# 📊 DETAILED COMBINATION ANALYSIS:
# ...
#
# Size Keywords                            Found    Overlap  Precision  Recall   F1
# --------------------------------------------------------------------------------
# 20   binary, light, contact...           930      198      21.3       46.7     29.2
# 15   binary, light, contact...           3235     288      8.9        67.9     15.7
# 10   binary, light, contact...           4417     314      7.1        74.1     13.0
# 7    binary, light, contact...           7448     340      4.6        80.2     8.6
# 5    binary, light, contact...           9020     352      3.9        83.0     7.5
#
# 💡 KEY INSIGHTS:
#
# 📈 TRENDS (as keyword count increases):
#    • Total papers found: Generally decreases (more restrictive)
#    • Precision: Generally increases (more relevant papers)
#    • Recall: May decrease (fewer WUMaCat papers found)
#
# 🎯 RECOMMENDED COMBINATION:
#    • 5 keywords: ['binary', 'light', 'contact', 'period', 'photometric']
# ...

# %% [markdown]
# ## 6. Abstract Search Experiment
#
# Now let's test exact keyword searches in abstracts with smaller keyword combinations [10, 5, 4, 3]. Abstracts are more concise than full text, so smaller combinations should still yield meaningful results.

# %%
# Test keyword combinations in abstracts
print("🔬 Running abstract search experiment...")
print("This will test smaller keyword combinations (10, 5, 4, 3) in abstract fields")
print("since abstracts are more concise and focused than full text.")

# Test smaller combination sizes in abstracts
abstract_combination_sizes = [10, 5, 4, 3, 2]
print(f"\n🎯 Available keywords: {len(top_keywords)}")
print(f"📊 Testing combination sizes in abstracts: {abstract_combination_sizes}")
print(f"🔍 Search field: abstracts (more focused than full text)")

# Run the abstract experiment
abstract_results = test_keyword_combination_sizes(
    all_keywords=top_keywords,
    wumacat_bibcodes=wumacat_bibcodes,
    combination_sizes=abstract_combination_sizes,
    source_field="abs"
)

print("\n✅ Abstract search experiment completed!")

# Display summary results
if abstract_results and 'summary' in abstract_results:
    summary = abstract_results['summary']
    print(f"\n🎯 ABSTRACT EXPERIMENT SUMMARY:")
    print(f"   Successful combinations: {summary.get('successful_combinations', [])}")
    
    if 'best_overlap' in summary:
        best_overlap = summary['best_overlap']
        print(f"   Best overlap: {best_overlap['percentage']:.1f}% with {best_overlap['size']} keywords")
    
    if 'best_precision' in summary:
        best_precision = summary['best_precision']
        print(f"   Best precision: {best_precision['percentage']:.1f}% with {best_precision['size']} keywords")
        
    if 'best_f1' in summary:
        best_f1 = summary['best_f1']
        print(f"   Best F1-score: {best_f1['score']:.1f}% with {best_f1['size']} keywords")
else:
    print("\n⚠️  Abstract experiment did not complete successfully")
# Out:
# 🔬 Running abstract search experiment...
# This will test smaller keyword combinations (10, 5, 4, 3) in abstract fields
# since abstracts are more concise and focused than full text.
#
# 🎯 Available keywords: 25
# 📊 Testing combination sizes in abstracts: [10, 5, 4, 3, 2]
# 🔍 Search field: abstracts (more focused than full text)
# 🧪 Testing keyword combination sizes in 'abs' field
#    Available keywords: 25
#    Combination sizes to test: [10, 5, 4, 3, 2]
#    WUMaCat reference size: 424
#
# 📊 Testing combination size: 10 keywords
#    Keywords: ['binary', 'light', 'contact', 'period', 'photometric', 'mass', 'type', 'curves', 'binaries', 'eclipsing']
# 🔍 Searching for exact keywords in abs field:
#    Keywords: ['binary', 'light', 'contact', 'period', 'photometric', 'mass', 'type', 'curves', 'binaries', 'eclipsing']
# ...

# %% [markdown]
# ## 7. Comprehensive Results Summary
#
# Let's compare and summarize the results from both full-text and abstract searches to identify the optimal search strategies.

# %%
# Comprehensive analysis of both full-text and abstract results
print("📋 COMPREHENSIVE RESULTS SUMMARY")
print("="*60)

print(f"\n🔍 FULL-TEXT SEARCH RESULTS:")
print("-" * 40)
if combination_results and 'combination_results' in combination_results:
    full_combo_results = combination_results['combination_results']
    
    print(f"{'Size':<4} {'Found':<8} {'Overlap':<8} {'Precision':<10} {'Recall':<8} {'F1':<6}")
    print("-" * 50)
    
    for size in sorted(full_combo_results.keys(), reverse=True):
        data = full_combo_results[size]
        if "error" not in data:
            found = data['total_found']
            overlap = data['overlap_count']
            precision = data.get('precision', 0)
            recall = data.get('overlap_percentage', 0)
            f1 = data.get('f1_score', 0)
            print(f"{size:<4} {found:<8} {overlap:<8} {precision:<10.1f} {recall:<8.1f} {f1:<6.1f}")

print(f"\n📄 ABSTRACT SEARCH RESULTS:")
print("-" * 40)
if abstract_results and 'combination_results' in abstract_results:
    abs_combo_results = abstract_results['combination_results']
    
    print(f"{'Size':<4} {'Found':<8} {'Overlap':<8} {'Precision':<10} {'Recall':<8} {'F1':<6}")
    print("-" * 50)
    
    for size in sorted(abs_combo_results.keys(), reverse=True):
        data = abs_combo_results[size]
        if "error" not in data:
            found = data['total_found']
            overlap = data['overlap_count']
            precision = data.get('precision', 0)
            recall = data.get('overlap_percentage', 0)
            f1 = data.get('f1_score', 0)
            print(f"{size:<4} {found:<8} {overlap:<8} {precision:<10.1f} {recall:<8.1f} {f1:<6.1f}")

# Find overall best strategies
print(f"\n🏆 BEST STRATEGIES COMPARISON:")
print("-" * 50)

all_strategies = []

# Add full-text strategies
if combination_results and 'combination_results' in combination_results:
    for size, data in combination_results['combination_results'].items():
        if "error" not in data and data['total_found'] > 0:
            all_strategies.append({
                'field': 'full',
                'size': size,
                'data': data
            })

# Add abstract strategies
if abstract_results and 'combination_results' in abstract_results:
    for size, data in abstract_results['combination_results'].items():
        if "error" not in data and data['total_found'] > 0:
            all_strategies.append({
                'field': 'abs',
                'size': size,
                'data': data
            })

if all_strategies:
    # Find best by different metrics
    best_precision = max(all_strategies, key=lambda x: x['data'].get('precision', 0))
    best_recall = max(all_strategies, key=lambda x: x['data'].get('overlap_percentage', 0))
    best_f1 = max(all_strategies, key=lambda x: x['data'].get('f1_score', 0))
    
    # Find best balanced strategy (good F1 + reasonable paper count)
    balanced_strategies = [s for s in all_strategies if s['data']['total_found'] >= 10 and s['data']['total_found'] <= 5000]
    if balanced_strategies:
        best_balanced = max(balanced_strategies, key=lambda x: x['data'].get('f1_score', 0))
    else:
        best_balanced = best_f1
    
    print(f"🎯 Best Precision: {best_precision['data'].get('precision', 0):.1f}% ")
    print(f"   → {best_precision['field']} field, {best_precision['size']} keywords")
    print(f"   → Found {best_precision['data']['total_found']} papers, {best_precision['data']['overlap_count']} WUMaCat overlaps")
    
    print(f"\n📊 Best Recall: {best_recall['data'].get('overlap_percentage', 0):.1f}%")
    print(f"   → {best_recall['field']} field, {best_recall['size']} keywords")
    print(f"   → Found {best_recall['data']['total_found']} papers, {best_recall['data']['overlap_count']} WUMaCat overlaps")
    
    print(f"\n⚖️  Best F1-Score: {best_f1['data'].get('f1_score', 0):.1f}%")
    print(f"   → {best_f1['field']} field, {best_f1['size']} keywords")
    print(f"   → Found {best_f1['data']['total_found']} papers, {best_f1['data']['overlap_count']} WUMaCat overlaps")
    
    print(f"\n🎯 RECOMMENDED STRATEGY (Best Balanced):")
    print(f"   → {best_balanced['field']} field, {best_balanced['size']} keywords")
    print(f"   → F1-Score: {best_balanced['data'].get('f1_score', 0):.1f}%")
    print(f"   → Precision: {best_balanced['data'].get('precision', 0):.1f}% | Recall: {best_balanced['data'].get('overlap_percentage', 0):.1f}%")
    print(f"   → Found {best_balanced['data']['total_found']} papers, {best_balanced['data']['overlap_count']} WUMaCat overlaps")
    print(f"   → Keywords: {best_balanced['data']['keywords'][:5]}..." if len(best_balanced['data']['keywords']) > 5 else f"   → Keywords: {best_balanced['data']['keywords']}")

print(f"\n💡 KEY INSIGHTS:")
print(f"   • Full-text searches: Better for comprehensive discovery")
print(f"   • Abstract searches: Better precision with fewer keywords")
print(f"   • Optimal range: Likely 4-10 keywords depending on field")
print(f"   • Use full-text for broad discovery, abstracts for focused reviews")

# Save comprehensive results
experiment_summary = {
    "full_text_results": combination_results,
    "abstract_results": abstract_results,
    "best_strategies": {
        "best_precision": {
            "field": best_precision['field'],
            "size": best_precision['size'],
            "precision": best_precision['data'].get('precision', 0)
        } if 'best_precision' in locals() else None,
        "best_recall": {
            "field": best_recall['field'], 
            "size": best_recall['size'],
            "recall": best_recall['data'].get('overlap_percentage', 0)
        } if 'best_recall' in locals() else None,
        "recommended": {
            "field": best_balanced['field'],
            "size": best_balanced['size'],
            "f1_score": best_balanced['data'].get('f1_score', 0),
            "keywords": best_balanced['data']['keywords']
        } if 'best_balanced' in locals() else None
    }
}

# Save results
output_file = '../data/comprehensive_keyword_experiment_results.json'
save_experiment_results(experiment_summary, output_file)

print(f"\n✅ Comprehensive analysis completed!")
print(f"📄 Results saved to: {output_file}")
# Out:
# 📋 COMPREHENSIVE RESULTS SUMMARY
# ...
#
# 🔍 FULL-TEXT SEARCH RESULTS:
# ----------------------------------------
# Size Found    Overlap  Precision  Recall   F1
# --------------------------------------------------
# 20   930      198      21.3       46.7     29.2
# 15   3235     288      8.9        67.9     15.7
# 10   4417     314      7.1        74.1     13.0
# 7    7448     340      4.6        80.2     8.6
# 5    9020     352      3.9        83.0     7.5
#
# 📄 ABSTRACT SEARCH RESULTS:
# ----------------------------------------
# Size Found    Overlap  Precision  Recall   F1
# --------------------------------------------------
# 10   158      56       35.4       13.2     19.2
# 5    669      158      23.6       37.3     28.9
# 4    1152     196      17.0       46.2     24.9
# 3    2040     264      12.9       62.3     21.4
# 2    28638    322      1.6        75.9     3.2
#
# 🏆 BEST STRATEGIES COMPARISON:
# --------------------------------------------------
# 🎯 Best Precision: 35.4%
# ...

# %%
## Check for Existing Results and Load Them

# Check if experiment results already exist and load them for visualization
print("🔍 Checking for existing experiment results...")

# Define file paths
comprehensive_results_file = '../data/comprehensive_keyword_experiment_results.json'
comparison_csv_file = '../data/exact_keyword_experiment_comparison.csv'

# Try to load existing results
existing_results = {}
loaded_from_files = []

# Check for comprehensive results (contains both full-text and abstract)
if os.path.exists(comprehensive_results_file):
    try:
        with open(comprehensive_results_file, 'r', encoding='utf-8') as f:
            existing_results['comprehensive'] = json.load(f)
        loaded_from_files.append('comprehensive results')
        print(f"✅ Loaded existing comprehensive results from: {comprehensive_results_file}")
    except Exception as e:
        print(f"⚠️  Could not load {comprehensive_results_file}: {e}")

# Check for comparison CSV
if os.path.exists(comparison_csv_file):
    try:
        comparison_df = pd.read_csv(comparison_csv_file)
        existing_results['comparison'] = comparison_df
        loaded_from_files.append('comparison CSV')
        print(f"✅ Loaded existing comparison data from: {comparison_csv_file}")
    except Exception as e:
        print(f"⚠️  Could not load {comparison_csv_file}: {e}")

# Extract results for visualization
if 'comprehensive' in existing_results:
    # Extract from comprehensive results
    comp_data = existing_results['comprehensive']
    
    # Check the structure and extract data
    if 'results' in comp_data:
        results_data = comp_data['results']
        
        # Extract full-text results
        if 'full_text_results' in results_data:
            combination_results = results_data['full_text_results']
            print("✅ Extracted full-text results from comprehensive data")
        else:
            print("⚠️  Comprehensive data missing full_text_results")
            combination_results = None
            
        # Extract abstract results
        if 'abstract_results' in results_data:
            abstract_results = results_data['abstract_results']
            print("✅ Extracted abstract results from comprehensive data")
        else:
            print("⚠️  Comprehensive data missing abstract_results")
            abstract_results = None
            
    else:
        print("⚠️  Comprehensive data missing 'results' section")
        combination_results = None
        abstract_results = None
        
elif 'complete' in existing_results:
    # Extract from complete results (alternative structure)
    comp_data = existing_results['complete']
    if 'detailed_results' in comp_data:
        detailed = comp_data['detailed_results']
        combination_results = detailed.get('full_text_results')
        abstract_results = detailed.get('abstract_results')
        print("✅ Extracted full-text and abstract results from complete data")
    else:
        print("⚠️  Complete data missing detailed_results")
        combination_results = None
        abstract_results = None
else:
    print("❌ No existing results found. Please run the experiments first.")
    combination_results = None
    abstract_results = None

# Check if we have the necessary data for visualization
if combination_results and abstract_results:
    print(f"\n📊 Data loaded successfully for visualization:")
    
    # Check full-text results
    if 'combination_results' in combination_results:
        full_text_combos = combination_results['combination_results']
        print(f"   • Full-text results: {len(full_text_combos)} combinations")
        print(f"   • Full-text keyword counts: {sorted(full_text_combos.keys())}")
    else:
        print("   • Full-text results: ❌ Missing combination_results")
        
    # Check abstract results
    if 'combination_results' in abstract_results:
        abstract_combos = abstract_results['combination_results']
        print(f"   • Abstract results: {len(abstract_combos)} combinations")
        print(f"   • Abstract keyword counts: {sorted(abstract_combos.keys())}")
    else:
        print("   • Abstract results: ❌ Missing combination_results")
    
    print(f"   • Ready to create visualizations!")
    
    # Extract WUMaCat size from the data
    wumacat_size = None
    if combination_results and 'wumacat_size' in combination_results:
        wumacat_size = combination_results['wumacat_size']
        print(f"   • WUMaCat size from data: {wumacat_size}")
    elif abstract_results and 'wumacat_size' in abstract_results:
        wumacat_size = abstract_results['wumacat_size']
        print(f"   • WUMaCat size from data: {wumacat_size}")
    else:
        # Try to estimate from comparison data
        if 'comparison' in existing_results:
            comparison_data = existing_results['comparison']
            if 'Recall_%' in comparison_data.columns and 'WUMaCat_Overlaps' in comparison_data.columns:
                # Find a row with high recall to estimate WUMaCat size
                high_recall_rows = comparison_data[comparison_data['Recall_%'] > 80]
                if len(high_recall_rows) > 0:
                    high_recall_row = high_recall_rows.iloc[0]
                    estimated_wumacat_size = int(high_recall_row['WUMaCat_Overlaps'] / (high_recall_row['Recall_%'] / 100))
                    wumacat_size = estimated_wumacat_size
                    print(f"   • Estimated WUMaCat size: {wumacat_size} (from comparison data)")
                else:
                    wumacat_size = 424  # Default size
                    print(f"   • Using default WUMaCat size: {wumacat_size}")
            else:
                wumacat_size = 424  # Default size
                print(f"   • Using default WUMaCat size: {wumacat_size}")
        else:
            wumacat_size = 424  # Default size
            print(f"   • Using default WUMaCat size: {wumacat_size}")
    
    # Create a placeholder wumacat_bibcodes set for calculations
    wumacat_bibcodes = set(range(wumacat_size))
        
else:
    print(f"\n❌ Insufficient data for visualization:")
    print(f"   • combination_results: {'✅' if combination_results else '❌'}")
    print(f"   • abstract_results: {'✅' if abstract_results else '❌'}")
    
    # Debug: show what we actually loaded
    if existing_results:
        print(f"\n🔍 Debug - What was loaded:")
        for key, value in existing_results.items():
            if isinstance(value, dict):
                print(f"   • {key}: {list(value.keys())}")
            elif isinstance(value, pd.DataFrame):
                print(f"   • {key}: DataFrame with columns {list(value.columns)}")
            else:
                print(f"   • {key}: {type(value)}")
    
    print(f"   • Please run the experiments first or check file paths")

print(f"\n📁 Files loaded: {', '.join(loaded_from_files) if loaded_from_files else 'None'}")

# Final check - if we have the data, show a sample
if combination_results and abstract_results:
    print(f"\n🎯 Sample data verification:")
    
    # Check full-text sample
    if 'combination_results' in combination_results:
        full_sample = list(combination_results['combination_results'].keys())[0]
        full_data = combination_results['combination_results'][full_sample]
        print(f"   • Full-text sample ({full_sample} keywords): {full_data.get('total_found', 'N/A')} papers, {full_data.get('overlap_count', 'N/A')} overlaps")
    
    # Check abstract sample
    if 'combination_results' in abstract_results:
        abs_sample = list(abstract_results['combination_results'].keys())[0]
        abs_data = abstract_results['combination_results'][abs_sample]
        print(f"   • Abstract sample ({abs_sample} keywords): {abs_data.get('total_found', 'N/A')} papers, {abs_data.get('overlap_count', 'N/A')} overlaps")
# Out:
# 🔍 Checking for existing experiment results...
# ✅ Loaded existing comprehensive results from: ../data/comprehensive_keyword_experiment_results.json
# ✅ Loaded existing comparison data from: ../data/exact_keyword_experiment_comparison.csv
# ✅ Extracted full-text results from comprehensive data
# ✅ Extracted abstract results from comprehensive data
#
# 📊 Data loaded successfully for visualization:
#    • Full-text results: 5 combinations
#    • Full-text keyword counts: ['10', '15', '20', '5', '7']
#    • Abstract results: 5 combinations
#    • Abstract keyword counts: ['10', '2', '3', '4', '5']
#    • Ready to create visualizations!
#    • WUMaCat size from data: 424
#
# 📁 Files loaded: comprehensive results, comparison CSV
#
# 🎯 Sample data verification:
#    • Full-text sample (20 keywords): 930 papers, 198 overlaps
#    • Abstract sample (10 keywords): 158 papers, 56 overlaps

# %%
# Create visualizations of the abstract search experiment results
print("📊 Creating visualizations of abstract search experiment results...")

if abstract_results:
    # Prepare data for abstract results plotting
    abs_results = abstract_results.get('combination_results', {})
    
    # Fix the sorting issue: sort by numeric value, not string sorting
    abs_keyword_counts = sorted([int(k) for k, v in abs_results.items() if "error" not in v])
    abs_total_papers = [abs_results[str(k)]['total_found'] for k in abs_keyword_counts]
    
    # Fix the precision/recall issue: use the correct metrics from the data
    # Precision = (overlap_count / total_found) * 100
    # Recall = (overlap_count / wumacat_total) * 100
    abs_precision_values = []
    abs_recall_values = []
    abs_overlap_counts = []
    
    for k in abs_keyword_counts:
        data = abs_results[str(k)]
        overlap_count = data['overlap_count']
        total_found = data['total_found']
        
        # Calculate precision: percentage of found papers that are in WUMaCat
        precision = (overlap_count / total_found) * 100 if total_found > 0 else 0
        abs_precision_values.append(precision)
        
        # Calculate recall: percentage of WUMaCat papers that were found
        recall = (overlap_count / len(wumacat_bibcodes)) * 100 if len(wumacat_bibcodes) > 0 else 0
        abs_recall_values.append(recall)
        
        abs_overlap_counts.append(overlap_count)
    
    abs_new_discoveries = [abs_results[str(k)]['total_found'] - abs_results[str(k)]['overlap_count'] for k in abs_keyword_counts]

    # Create figure with subplots (2x2 layout like the original)
    fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(15, 12))
    fig.suptitle('Exact Keyword Search Experiment: Abstract Results Analysis',
                fontsize=16, fontweight='bold')

    # Plot 1: Total Papers Found vs Keyword Count
    ax1.plot(abs_keyword_counts, abs_total_papers, 'o-', linewidth=2, markersize=8, color='blue')
    ax1.set_xlabel('Number of Keywords')
    ax1.set_ylabel('Total Papers Found')
    ax1.set_title('Papers Found vs Keyword Count')
    ax1.grid(True, alpha=0.3)
    ax1.set_yscale('log')  # Log scale for better visualization

    # Add value labels
    for i, (x, y) in enumerate(zip(abs_keyword_counts, abs_total_papers)):
        ax1.annotate(f'{y:,}', (x, y), textcoords="offset points", xytext=(0,10), ha='center', fontsize=9)

    # Plot 2: Precision vs Keyword Count (FIXED: now shows actual precision)
    ax2.plot(abs_keyword_counts, abs_precision_values, 'o-', linewidth=2, markersize=8, color='green')
    ax2.set_xlabel('Number of Keywords')
    ax2.set_ylabel('Precision (%)')
    ax2.set_title('Precision vs Keyword Count')
    ax2.grid(True, alpha=0.3)
    ax2.set_ylim(0, max(abs_precision_values) * 1.1)

    # Add value labels
    for i, (x, y) in enumerate(zip(abs_keyword_counts, abs_precision_values)):
        ax2.annotate(f'{y:.1f}%', (x, y), textcoords="offset points", xytext=(0,10), ha='center', fontsize=9)

    # Plot 3: Recall (WUMaCat Coverage) vs Keyword Count (FIXED: now shows actual recall)
    ax3.plot(abs_keyword_counts, abs_recall_values, 'o-', linewidth=2, markersize=8, color='orange')
    ax3.set_xlabel('Number of Keywords')
    ax3.set_ylabel('Recall (%)')
    ax3.set_title('Recall (WUMaCat Coverage) vs Keyword Count')
    ax3.grid(True, alpha=0.3)
    ax3.set_ylim(0, max(abs_recall_values) * 1.1)

    # Add value labels
    for i, (x, y) in enumerate(zip(abs_keyword_counts, abs_recall_values)):
        ax3.annotate(f'{y:.1f}%', (x, y), textcoords="offset points", xytext=(0,10), ha='center', fontsize=9)

    # Plot 4: New Papers (not in WUMaCat) vs Keyword Count
    ax4.plot(abs_keyword_counts, abs_new_discoveries, 'o-', linewidth=2, markersize=8, color='red')
    ax4.set_xlabel('Number of Keywords')
    ax4.set_ylabel('New Discoveries')
    ax4.set_title('New Papers (not in WUMaCat) vs Keyword Count')
    ax4.grid(True, alpha=0.3)
    ax4.set_yscale('log')  # Log scale for better visualization

    # Add value labels
    for i, (x, y) in enumerate(zip(abs_keyword_counts, abs_new_discoveries)):
        ax4.annotate(f'{y:,}', (x, y), textcoords="offset points", xytext=(0,10), ha='center', fontsize=9)

    plt.tight_layout()

    # Save the figure
    abs_output_file = '../data/exact_keyword_experiment_abstract_results.png'
    plt.savefig(abs_output_file, dpi=300, bbox_inches='tight')
    print(f"✅ Abstract visualizations saved to: {abs_output_file}")

    plt.show()

    # Print key findings summary for abstracts
    print(f"\nKEY FINDINGS (ABSTRACTS):")
    print(f"   • Best precision: {max(abs_precision_values):.1f}% (with {abs_keyword_counts[abs_precision_values.index(max(abs_precision_values))]} keywords)")
    print(f"   • Best recall: {max(abs_recall_values):.1f}% (with {abs_keyword_counts[abs_recall_values.index(max(abs_recall_values))]} keywords)")
    print(f"   • Most papers: {max(abs_total_papers):,} (with {abs_keyword_counts[abs_total_papers.index(max(abs_total_papers))]} keywords)")
    print(f"   • Most WUMaCat coverage: {max(abs_recall_values):.1f}% (with {abs_keyword_counts[abs_recall_values.index(max(abs_recall_values))]} keywords)")

else:
    print("❌ No abstract experiment results available for visualization")
    print("   Please run the abstract experiment first.")
# Out:
# 📊 Creating visualizations of abstract search experiment results...
# ✅ Abstract visualizations saved to: ../data/exact_keyword_experiment_abstract_results.png
# KEY FINDINGS (ABSTRACTS):
#    • Best precision: 35.4% (with 10 keywords)
#    • Best recall: 75.9% (with 2 keywords)
#    • Most papers: 28,638 (with 2 keywords)
#    • Most WUMaCat coverage: 75.9% (with 2 keywords)

# %%
# Create visualizations of the full-text search results
print("📊 Creating visualizations of full-text search experiment results...")

if combination_results:
    # Prepare data for full-text results plotting
    full_results = combination_results.get('combination_results', {})
    
    # Fix the sorting issue: sort by numeric value, not string sorting
    full_keyword_counts = sorted([int(k) for k, v in full_results.items() if "error" not in v])
    full_total_papers = [full_results[str(k)]['total_found'] for k in full_keyword_counts]
    
    # Fix the precision/recall issue: use the correct metrics from the data
    # Precision = (overlap_count / total_found) * 100
    # Recall = (overlap_count / wumacat_total) * 100
    full_precision_values = []
    full_recall_values = []
    full_overlap_counts = []
    
    for k in full_keyword_counts:
        data = full_results[str(k)]
        overlap_count = data['overlap_count']
        total_found = data['total_found']
        
        # Calculate precision: percentage of found papers that are in WUMaCat
        precision = (overlap_count / total_found) * 100 if total_found > 0 else 0
        full_precision_values.append(precision)
        
        # Calculate recall: percentage of WUMaCat papers that were found
        recall = (overlap_count / len(wumacat_bibcodes)) * 100 if len(wumacat_bibcodes) > 0 else 0
        full_recall_values.append(recall)
        
        full_overlap_counts.append(overlap_count)
    
    full_new_discoveries = [full_results[str(k)]['total_found'] - full_results[str(k)]['overlap_count'] for k in full_keyword_counts]

    # Create figure with subplots (2x2 layout)
    fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(15, 12))
    fig.suptitle('Exact Keyword Search Experiment: Full-Text Results Analysis',
                fontsize=16, fontweight='bold')

    # Plot 1: Total Papers Found vs Keyword Count
    ax1.plot(full_keyword_counts, full_total_papers, 'o-', linewidth=2, markersize=8, color='blue')
    ax1.set_xlabel('Number of Keywords')
    ax1.set_ylabel('Total Papers Found')
    ax1.set_title('Papers Found vs Keyword Count')
    ax1.grid(True, alpha=0.3)
    ax1.set_yscale('log')  # Log scale for better visualization

    # Add value labels
    for i, (x, y) in enumerate(zip(full_keyword_counts, full_total_papers)):
        ax1.annotate(f'{y:,}', (x, y), textcoords="offset points", xytext=(0,10), ha='center', fontsize=9)

    # Plot 2: Precision vs Keyword Count (FIXED: now shows actual precision)
    ax2.plot(full_keyword_counts, full_precision_values, 'o-', linewidth=2, markersize=8, color='green')
    ax2.set_xlabel('Number of Keywords')
    ax2.set_ylabel('Precision (%)')
    ax2.set_title('Precision vs Keyword Count')
    ax2.grid(True, alpha=0.3)
    ax2.set_ylim(0, max(full_precision_values) * 1.1)

    # Add value labels
    for i, (x, y) in enumerate(zip(full_keyword_counts, full_precision_values)):
        ax2.annotate(f'{y:.1f}%', (x, y), textcoords="offset points", xytext=(0,10), ha='center', fontsize=9)

    # Plot 3: Recall (WUMaCat Coverage) vs Keyword Count (FIXED: now shows actual recall)
    ax3.plot(full_keyword_counts, full_recall_values, 'o-', linewidth=2, markersize=8, color='orange')
    ax3.set_xlabel('Number of Keywords')
    ax3.set_ylabel('Recall (%)')
    ax3.set_title('Recall (WUMaCat Coverage) vs Keyword Count')
    ax3.grid(True, alpha=0.3)
    ax3.set_ylim(0, max(full_recall_values) * 1.1)

    # Add value labels
    for i, (x, y) in enumerate(zip(full_keyword_counts, full_recall_values)):
        ax3.annotate(f'{y:.1f}%', (x, y), textcoords="offset points", xytext=(0,10), ha='center', fontsize=9)

    # Plot 4: New Papers (not in WUMaCat) vs Keyword Count
    ax4.plot(full_keyword_counts, full_new_discoveries, 'o-', linewidth=2, markersize=8, color='red')
    ax4.set_xlabel('Number of Keywords')
    ax4.set_ylabel('New Discoveries')
    ax4.set_title('New Papers (not in WUMaCat) vs Keyword Count')
    ax4.grid(True, alpha=0.3)
    ax4.set_yscale('log')  # Log scale for better visualization

    # Add value labels
    for i, (x, y) in enumerate(zip(full_keyword_counts, full_new_discoveries)):
        ax4.annotate(f'{y:,}', (x, y), textcoords="offset points", xytext=(0,10), ha='center', fontsize=9)

    plt.tight_layout()

    # Save the figure
    full_output_file = '../data/exact_keyword_experiment_fulltext_results.png'
    plt.savefig(full_output_file, dpi=300, bbox_inches='tight')
    print(f"✅ Full-text visualizations saved to: {full_output_file}")

    plt.show()

    # Print key findings summary for full-text
    print(f"\nKEY FINDINGS (FULL-TEXT):")
    print(f"   • Best precision: {max(full_precision_values):.1f}% (with {full_keyword_counts[full_precision_values.index(max(full_precision_values))]} keywords)")
    print(f"   • Best recall: {max(full_recall_values):.1f}% (with {full_keyword_counts[full_recall_values.index(max(full_recall_values))]} keywords)")
    print(f"   • Most papers: {max(full_total_papers):,} (with {full_keyword_counts[full_total_papers.index(max(full_total_papers))]} keywords)")
    print(f"   • Most WUMaCat coverage: {max(full_recall_values):.1f}% (with {full_keyword_counts[full_recall_values.index(max(full_recall_values))]} keywords)")

else:
    print("❌ No full-text experiment results available for visualization")
    print("   Please run the full-text experiment first.")
# Out:
# 📊 Creating visualizations of full-text search experiment results...
# ✅ Full-text visualizations saved to: ../data/exact_keyword_experiment_fulltext_results.png
# KEY FINDINGS (FULL-TEXT):
#    • Best precision: 21.3% (with 20 keywords)
#    • Best recall: 83.0% (with 5 keywords)
#    • Most papers: 9,020 (with 5 keywords)
#    • Most WUMaCat coverage: 83.0% (with 5 keywords)

# %%
# Create detailed comparison tables and save comprehensive results
print("📊 Creating detailed comparison tables and saving results...")

if combination_results and abstract_results:
    # Create comprehensive DataFrame for analysis
    comparison_data = []
    
    # Add full-text results
    if 'combination_results' in combination_results:
        for size, data in combination_results['combination_results'].items():
            if "error" not in data:
                comparison_data.append({
                    'Search_Field': 'Full-text',
                    'Keywords_Count': size,
                    'Keywords': ', '.join(data['keywords'][:3]) + ('...' if len(data['keywords']) > 3 else ''),
                    'Total_Papers': data['total_found'],
                    'WUMaCat_Overlaps': data['overlap_count'],
                    'Precision_%': data.get('precision', 0),
                    'Recall_%': data.get('overlap_percentage', 0),
                    'F1_Score_%': data.get('f1_score', 0),
                    'Efficiency': data['total_found'] / max(1, data['overlap_count']),
                    'Keywords_List': data['keywords']
                })
    
    # Add abstract results  
    if 'combination_results' in abstract_results:
        for size, data in abstract_results['combination_results'].items():
            if "error" not in data:
                comparison_data.append({
                    'Search_Field': 'Abstract',
                    'Keywords_Count': size,
                    'Keywords': ', '.join(data['keywords'][:3]) + ('...' if len(data['keywords']) > 3 else ''),
                    'Total_Papers': data['total_found'],
                    'WUMaCat_Overlaps': data['overlap_count'],
                    'Precision_%': data.get('precision', 0),
                    'Recall_%': data.get('overlap_percentage', 0),
                    'F1_Score_%': data.get('f1_score', 0),
                    'Efficiency': data['total_found'] / max(1, data['overlap_count']),
                    'Keywords_List': data['keywords']
                })
    
    # Create DataFrame
    comparison_df = pd.DataFrame(comparison_data)
    comparison_df = comparison_df.sort_values(['Search_Field', 'Keywords_Count'], ascending=[True, False])
    
    print("\\n📊 COMPREHENSIVE STRATEGY COMPARISON TABLE:")
    print("=" * 120)
    
    # Display formatted table
    pd.set_option('display.max_columns', None)
    pd.set_option('display.width', None)
    pd.set_option('display.max_colwidth', 30)
    
    print(comparison_df[['Search_Field', 'Keywords_Count', 'Total_Papers', 'WUMaCat_Overlaps', 
                        'Precision_%', 'Recall_%', 'F1_Score_%', 'Efficiency']].to_string(index=False))
    
    print("\\n🏆 TOP PERFORMING STRATEGIES:")
    print("-" * 60)
    
    # Find top strategies by different metrics
    top_precision = comparison_df.loc[comparison_df['Precision_%'].idxmax()]
    top_recall = comparison_df.loc[comparison_df['Recall_%'].idxmax()]
    top_f1 = comparison_df.loc[comparison_df['F1_Score_%'].idxmax()]
    min_efficiency = comparison_df.loc[comparison_df['Efficiency'].idxmin()]
    
    print(f"🎯 Best Precision: {top_precision['Precision_%']:.1f}%")
    print(f"   → {top_precision['Search_Field']} field, {top_precision['Keywords_Count']} keywords")
    print(f"   → {top_precision['Total_Papers']:,} papers, {top_precision['WUMaCat_Overlaps']} WUMaCat hits")
    
    print(f"\\n📊 Best Recall: {top_recall['Recall_%']:.1f}%")
    print(f"   → {top_recall['Search_Field']} field, {top_recall['Keywords_Count']} keywords") 
    print(f"   → {top_recall['Total_Papers']:,} papers, {top_recall['WUMaCat_Overlaps']} WUMaCat hits")
    
    print(f"\\n⚖️  Best F1-Score: {top_f1['F1_Score_%']:.1f}%")
    print(f"   → {top_f1['Search_Field']} field, {top_f1['Keywords_Count']} keywords")
    print(f"   → {top_f1['Total_Papers']:,} papers, {top_f1['WUMaCat_Overlaps']} WUMaCat hits")
    
    print(f"\\n🚀 Most Efficient: {min_efficiency['Efficiency']:.1f} papers/WUMaCat hit")
    print(f"   → {min_efficiency['Search_Field']} field, {min_efficiency['Keywords_Count']} keywords")
    print(f"   → {min_efficiency['Total_Papers']:,} papers, {min_efficiency['WUMaCat_Overlaps']} WUMaCat hits")
    
    # Create use-case recommendations
    print(f"\\n💡 USE-CASE RECOMMENDATIONS:")
    print("-" * 40)
    
    # Find balanced strategies for different use cases
    high_precision_strategies = comparison_df[comparison_df['Precision_%'] >= 20]
    high_recall_strategies = comparison_df[comparison_df['Recall_%'] >= 75]
    balanced_strategies = comparison_df[
        (comparison_df['F1_Score_%'] >= 20) & 
        (comparison_df['Total_Papers'] >= 100) & 
        (comparison_df['Total_Papers'] <= 5000)
    ]
    
    if not high_precision_strategies.empty:
        best_precision_strategy = high_precision_strategies.loc[high_precision_strategies['F1_Score_%'].idxmax()]
        print(f"🎯 For High Precision Literature Review:")
        print(f"   → Use {best_precision_strategy['Search_Field']} field with {best_precision_strategy['Keywords_Count']} keywords")
        print(f"   → Expected: ~{best_precision_strategy['Total_Papers']:,} papers, {best_precision_strategy['Precision_%']:.1f}% relevant")
    
    if not high_recall_strategies.empty:
        best_recall_strategy = high_recall_strategies.loc[high_recall_strategies['F1_Score_%'].idxmax()]
        print(f"\\n📚 For Comprehensive Discovery:")
        print(f"   → Use {best_recall_strategy['Search_Field']} field with {best_recall_strategy['Keywords_Count']} keywords")
        print(f"   → Expected: ~{best_recall_strategy['Total_Papers']:,} papers, {best_recall_strategy['Recall_%']:.1f}% WUMaCat coverage")
    
    if not balanced_strategies.empty:
        best_balanced_strategy = balanced_strategies.loc[balanced_strategies['F1_Score_%'].idxmax()]
        print(f"\\n⚖️  For Balanced Research:")
        print(f"   → Use {best_balanced_strategy['Search_Field']} field with {best_balanced_strategy['Keywords_Count']} keywords")
        print(f"   → Expected: ~{best_balanced_strategy['Total_Papers']:,} papers, {best_balanced_strategy['F1_Score_%']:.1f}% F1-score")
    
    # Save comprehensive results
    results_summary = {
        'experiment_metadata': {
            'experiment_date': pd.Timestamp.now().isoformat(),
            'experiment_type': 'exact_keyword_search',
            'search_fields_tested': ['full', 'abs'],
            'keyword_combinations_tested': {
                'full_text': sorted(combination_results['combination_results'].keys()) if 'combination_results' in combination_results else [],
                'abstract': sorted(abstract_results['combination_results'].keys()) if 'combination_results' in abstract_results else []
            },
            'wumacat_baseline_size': len(wumacat_bibcodes),
            'top_keywords_used': top_keywords[:10]
        },
        'results_summary': {
            'best_precision': {
                'field': top_precision['Search_Field'],
                'keywords_count': top_precision['Keywords_Count'],
                'precision': top_precision['Precision_%'],
                'keywords': top_precision['Keywords_List']
            },
            'best_recall': {
                'field': top_recall['Search_Field'],
                'keywords_count': top_recall['Keywords_Count'],
                'recall': top_recall['Recall_%'],
                'keywords': top_recall['Keywords_List']
            },
            'best_f1': {
                'field': top_f1['Search_Field'],
                'keywords_count': top_f1['Keywords_Count'],
                'f1_score': top_f1['F1_Score_%'],
                'keywords': top_f1['Keywords_List']
            },
            'most_efficient': {
                'field': min_efficiency['Search_Field'],
                'keywords_count': min_efficiency['Keywords_Count'],
                'efficiency': min_efficiency['Efficiency'],
                'keywords': min_efficiency['Keywords_List']
            }
        },
        'detailed_results': {
            'full_text_results': combination_results,
            'abstract_results': abstract_results
        }
    }
    
    # Save detailed comparison table
    csv_file = '../data/exact_keyword_experiment_comparison.csv'
    comparison_df.to_csv(csv_file, index=False)
    print(f"\\n✅ Detailed comparison table saved to: {csv_file}")
    
    # Save comprehensive results
    json_file = '../data/exact_keyword_experiment_complete_results.json'
    with open(json_file, 'w', encoding='utf-8') as f:
        json.dump(results_summary, f, indent=2, ensure_ascii=False)
    print(f"✅ Complete experiment results saved to: {json_file}")
    
    print(f"\\n🎉 EXACT KEYWORD EXPERIMENT COMPLETED SUCCESSFULLY!")
    print(f"📁 All results and visualizations saved to '../data/' directory")
    
else:
    print("❌ Cannot create comparison table - missing experiment results")
    print("   Please run both full-text and abstract experiments first.")
# Out:
# 📊 Creating detailed comparison tables and saving results...
# \n📊 COMPREHENSIVE STRATEGY COMPARISON TABLE:
# ...
# Search_Field Keywords_Count  Total_Papers  WUMaCat_Overlaps  Precision_%  Recall_%  F1_Score_%  Efficiency
#     Abstract              5           669               158    23.617339 37.264151   28.911253    4.234177
#     Abstract              4          1152               196    17.013889 46.226415   24.873096    5.877551
#     Abstract              3          2040               264    12.941176 62.264151   21.428571    7.727273
#     Abstract              2         28638               322     1.610000 75.943396    3.153153   88.937888
#     Abstract             10           158                56    35.443038 13.207547   19.243986    2.821429
#    Full-text              7          7448               340     4.564984 80.188679    8.638211   21.905882
#    Full-text              5          9020               352     3.902439 83.018868    7.454468   25.625000
# ...

# %%
# Coverage Growth Rate Analysis - Corrected Version
# Plot coverage (recall) vs number of keywords, showing growth rate per 1000 papers

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os

print("📊 Coverage Growth Rate Analysis")
print("=" * 50)

# Define file paths
exact_keyword_csv = '../data/exact_keyword_experiment_comparison.csv'
semantic_csv = '../data/keyword_experiment_growth_analysis.csv'

# Load data
experiments = {}

# Load exact keyword experiment data
if os.path.exists(exact_keyword_csv):
    try:
        exact_data = pd.read_csv(exact_keyword_csv)
        # Filter for abstract results only
        exact_abstract = exact_data[exact_data['Search_Field'] == 'Abstract'].copy()
        exact_abstract['Keywords_Count'] = exact_abstract['Keywords_Count'].astype(int)
        exact_abstract = exact_abstract.sort_values('Keywords_Count', ascending=False)
        experiments['Exact Keywords'] = exact_abstract
        print(f"✅ Loaded exact keyword data: {len(exact_abstract)} combinations")
    except Exception as e:
        print(f"⚠️  Could not load exact keyword data: {e}")

# Load semantic search data
if os.path.exists(semantic_csv):
    try:
        semantic_data = pd.read_csv(semantic_csv)
        semantic_data['Keywords_Count'] = semantic_data['Keywords_Count'].astype(int)
        semantic_data = semantic_data.sort_values('Keywords_Count', ascending=False)
        experiments['Semantic Search'] = semantic_data
        print(f"✅ Loaded semantic search data: {len(semantic_data)} combinations")
    except Exception as e:
        print(f"⚠️  Could not load semantic search data: {e}")

if not experiments:
    print("❌ No data available for plotting")
else:
    # Create the plot
    plt.figure(figsize=(12, 8))
    
    colors = ['#1f77b4', '#ff7f0e', '#2ca02c']
    markers = ['o', 's', '^']
    
    legend_handles = []  # Store legend handles
    
    for i, (exp_name, data) in enumerate(experiments.items()):
        if len(data) > 0:
            # Sort by keyword count (descending)
            data_sorted = data.sort_values('Keywords_Count', ascending=False)
            
            # Calculate growth rate per 1000 papers for each keyword transition
            keyword_counts = []
            growth_rates = []
            
            for j in range(len(data_sorted) - 1):
                current = data_sorted.iloc[j]
                next_row = data_sorted.iloc[j + 1]
                
                # Calculate papers difference (next - current, since we're going from more to fewer keywords)
                papers_diff = next_row['Total_Papers'] - current['Total_Papers']
                if papers_diff > 0:
                    # Calculate coverage difference (next - current, since recall should increase with fewer keywords)
                    coverage_diff = next_row['Recall_%'] - current['Recall_%']
                    
                    # Growth rate per 1000 papers
                    growth_per_1000 = (coverage_diff / papers_diff) * 1000
                    
                    # Use the current keyword count (higher number) for x-axis
                    keyword_counts.append(current['Keywords_Count'])
                    growth_rates.append(growth_per_1000)
            
            if growth_rates:
                line, = plt.plot(keyword_counts, growth_rates, 
                               marker=markers[i], linewidth=2, markersize=8,
                               label=f'{exp_name}', color=colors[i])
                legend_handles.append(line)
                
                # Add annotations for papers found
                for j, (keywords, growth) in enumerate(zip(keyword_counts, growth_rates)):
                    papers = data_sorted.iloc[j]['Total_Papers']
                    plt.annotate(f'{papers:,}', 
                               (keywords, growth), 
                               textcoords="offset points", 
                               xytext=(0,10), 
                               ha='center', fontsize=9)
    
    # Only create legend if we have handles
    if legend_handles:
        plt.legend(handles=legend_handles, fontsize=11)
        plt.xlabel('Number of Keywords Used', fontsize=12)
        plt.ylabel('Coverage Growth per 1000 Papers (%)', fontsize=12)
        plt.title('Coverage Growth Rate vs Number of Keywords\n(How fast coverage increases when papers increase)', fontsize=14)
        plt.grid(True, alpha=0.3)
        
        # Add horizontal line at y=0 for reference
        plt.axhline(y=0, color='gray', linestyle='--', alpha=0.5)
        
        # Format y-axis to show percentage
        plt.gca().yaxis.set_major_formatter(plt.FuncFormatter(lambda y, _: '{:.2f}%'.format(y)))
        
        # Format x-axis to show integer keyword counts
        plt.gca().xaxis.set_major_locator(plt.MaxNLocator(integer=True))
        
        plt.tight_layout()
        plt.show()
    else:
        print("❌ No valid data to plot")
    
    # Print summary statistics
    print("\n📈 Growth Rate Summary:")
    print("-" * 40)
    
    for exp_name, data in experiments.items():
        if len(data) > 0:
            data_sorted = data.sort_values('Keywords_Count', ascending=False)
            print(f"\n{exp_name}:")
            
            for j in range(len(data_sorted) - 1):
                current = data_sorted.iloc[j]
                next_row = data_sorted.iloc[j + 1]
                
                papers_diff = next_row['Total_Papers'] - current['Total_Papers']
                if papers_diff > 0:
                    coverage_diff = next_row['Recall_%'] - current['Recall_%']
                    growth_per_1000 = (coverage_diff / papers_diff) * 1000
                    
                    print(f"  {current['Keywords_Count']} → {next_row['Keywords_Count']} keywords: "
                          f"{growth_per_1000:.3f}% coverage growth per 1000 papers")
# Out:
# 📊 Coverage Growth Rate Analysis
# ...
# ✅ Loaded exact keyword data: 5 combinations
# ✅ Loaded semantic search data: 5 combinations
# 📈 Growth Rate Summary:
# ----------------------------------------
#
# Exact Keywords:
#   10 → 5 keywords: 47.078% coverage growth per 1000 papers
#   5 → 4 keywords: 18.555% coverage growth per 1000 papers
#   4 → 3 keywords: 18.061% coverage growth per 1000 papers
#   3 → 2 keywords: 0.514% coverage growth per 1000 papers
#
# Semantic Search:
#   20 → 15 keywords: 5.000% coverage growth per 1000 papers
#   15 → 10 keywords: 2.035% coverage growth per 1000 papers
#   10 → 7 keywords: 0.545% coverage growth per 1000 papers
#   7 → 5 keywords: 1.053% coverage growth per 1000 papers
